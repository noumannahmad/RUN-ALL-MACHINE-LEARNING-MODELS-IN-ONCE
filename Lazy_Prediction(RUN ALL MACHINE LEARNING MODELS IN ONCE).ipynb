# %%
# Installation
# !pip install lazypredict
# Out:
# Collecting lazypredict
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# resampy 0.2.2 requires numba>=0.32, which is not installed.
# librosa 0.7.2 requires numba>=0.43.0, which is not installed.
# tensorflow 2.4.1 requires numpy~=1.19.2, but you'll have numpy 1.19.1 which is incompatible.
#   Downloading lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# Collecting scipy==1.5.4
#   Downloading scipy-1.5.4-cp38-cp38-win_amd64.whl (31.4 MB)
# Requirement already satisfied: six==1.15.0 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from lazypredict) (1.15.0)
# Collecting tqdm==4.56.0
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
# Collecting pandas==1.0.5
#   Downloading pandas-1.0.5-cp38-cp38-win_amd64.whl (8.9 MB)
# Requirement already satisfied: PyYAML==5.3.1 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from lazypredict) (5.3.1)
# Collecting lightgbm==2.3.1
#   Downloading lightgbm-2.3.1-py2.py3-none-win_amd64.whl (544 kB)
# Requirement already satisfied: click==7.1.2 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from lazypredict) (7.1.2)
# Collecting pytest==5.4.3
#   Downloading pytest-5.4.3-py3-none-any.whl (248 kB)
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp38-cp38-win_amd64.whl (6.8 MB)
# Collecting xgboost==1.1.1
#   Downloading xgboost-1.1.1-py3-none-win_amd64.whl (54.4 MB)
# Collecting numpy==1.19.1
#   Downloading numpy-1.19.1-cp38-cp38-win_amd64.whl (13.0 MB)
# Collecting joblib==1.0.0
#   Downloading joblib-1.0.0-py3-none-any.whl (302 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pandas==1.0.5->lazypredict) (2020.1)
# Requirement already satisfied: py>=1.5.0 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.9.0)
# Requirement already satisfied: packaging in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.4)
# Requirement already satisfied: wcwidth in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.2.5)
# Requirement already satisfied: atomicwrites>=1.0; sys_platform == "win32" in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (1.4.0)
# Requirement already satisfied: more-itertools>=4.0.0 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (8.6.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.4.4)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (20.3.0)
# Requirement already satisfied: pluggy<1.0,>=0.12 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nouman ahmad\anaconda3\lib\site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.7)
# Installing collected packages: numpy, scipy, tqdm, pandas, joblib, scikit-learn, lightgbm, pytest, xgboost, lazypredict
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.2
#     Uninstalling numpy-1.19.2:
#       Successfully uninstalled numpy-1.19.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.50.2
#     Uninstalling tqdm-4.50.2:
#       Successfully uninstalled tqdm-4.50.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.17.0
#     Uninstalling joblib-0.17.0:
#       Successfully uninstalled joblib-0.17.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 0.0.0
#     Uninstalling pytest-0.0.0:
#       Successfully uninstalled pytest-0.0.0
# Successfully installed joblib-1.0.0 lazypredict-0.2.9 lightgbm-2.3.1 numpy-1.19.1 pandas-1.0.5 pytest-5.4.3 scikit-learn-0.23.1 scipy-1.5.4 tqdm-4.56.0 xgboost-1.1.1

# %% [markdown]
# # Classification

# %%
# Imports
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import datasets

# %%
# Load our toy dataset
df = datasets.load_breast_cancer()
type(df)
# Out:
# sklearn.utils.Bunch

# %%
# Transform to Pandas dataframe if you want to explore the data
df2 = pd.DataFrame( df.data , columns=df.feature_names)
df2['target'] = df.target
df2.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80    1001.00             0.12
# 1        20.57         17.77          132.90    1326.00             0.08
# 2        19.69         21.25          130.00    1203.00             0.11
# 3        11.42         20.38           77.58     386.10             0.14
# 4        20.29         14.34          135.10    1297.00             0.10
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0              0.28            0.30                 0.15           0.24
# 1              0.08            0.09                 0.07           0.18
# 2              0.16            0.20                 0.13           0.21
# 3              0.28            0.24                 0.11           0.26
# 4              0.13            0.20                 0.10           0.18
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                    0.08  ...          17.33           184.60     2019.00
# 1                    0.06  ...          23.41           158.80     1956.00
# 2                    0.06  ...          25.53           152.50     1709.00
# 3                    0.10  ...          26.50            98.87      567.70
# 4                    0.06  ...          16.67           152.20     1575.00
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0              0.16               0.67             0.71                  0.27
# 1              0.12               0.19             0.24                  0.19
# 2              0.14               0.42             0.45                  0.24
# 3              0.21               0.87             0.69                  0.26
# 4              0.14               0.20             0.40                  0.16
#
#    worst symmetry  worst fractal dimension  target
# 0            0.46                     0.12       0
# 1            0.28                     0.09       0
# 2            0.36                     0.09       0
# 3            0.66                     0.17       0
# 4            0.24                     0.08       0
#
# [5 rows x 31 columns]

# %%
# X and Y
X, y = df.data, df.target

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2,random_state=12)

# %%
# Fit all models
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 25.23it/s]
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.97               0.97     0.97      0.97
# LogisticRegression                 0.97               0.97     0.97      0.97
# Perceptron                         0.97               0.97     0.97      0.97
# SGDClassifier                      0.96               0.96     0.96      0.96
# PassiveAggressiveClassifier        0.96               0.96     0.96      0.96
# RidgeClassifierCV                  0.96               0.95     0.95      0.96
# RidgeClassifier                    0.96               0.95     0.95      0.96
# ExtraTreesClassifier               0.96               0.95     0.95      0.96
# KNeighborsClassifier               0.96               0.95     0.95      0.96
# XGBClassifier                      0.95               0.94     0.94      0.95
# QuadraticDiscriminantAnalysis      0.95               0.94     0.94      0.95
# SVC                                0.95               0.94     0.94      0.95
# LGBMClassifier                     0.95               0.94     0.94      0.95
# LinearDiscriminantAnalysis         0.95               0.94     0.94      0.95
# AdaBoostClassifier                 0.94               0.93     0.93      0.94
# NuSVC                              0.94               0.93     0.93      0.94
# CalibratedClassifierCV             0.94               0.93     0.93      0.94
# BernoulliNB                        0.93               0.93     0.93      0.93
# LabelSpreading                     0.93               0.92     0.92      0.93
# LabelPropagation                   0.93               0.92     0.92      0.93
# RandomForestClassifier             0.93               0.92     0.92      0.93
# NearestCentroid                    0.93               0.92     0.92      0.93
# BaggingClassifier                  0.92               0.91     0.91      0.92
# GaussianNB                         0.92               0.91     0.91      0.92
# ExtraTreeClassifier                0.91               0.91     0.91      0.91
# DecisionTreeClassifier             0.91               0.91     0.91      0.91
# DummyClassifier                    0.54               0.52     0.52      0.53
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# LogisticRegression                   0.03
# Perceptron                           0.02
# SGDClassifier                        0.01
# PassiveAggressiveClassifier          0.02
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# ExtraTreesClassifier                 0.12
# KNeighborsClassifier                 0.02
# XGBClassifier                        0.05
# QuadraticDiscriminantAnalysis        0.02
# SVC                                  0.01
# LGBMClassifier                       0.09
# LinearDiscriminantAnalysis           0.02
# AdaBoostClassifier                   0.18
# NuSVC                                0.03
# CalibratedClassifierCV               0.04
# BernoulliNB                          0.01
# LabelSpreading                       0.04
# LabelPropagation                     0.03
# RandomForestClassifier               0.21
# NearestCentroid                      0.01
# BaggingClassifier                    0.06
# GaussianNB                           0.02
# ExtraTreeClassifier                  0.01
# DecisionTreeClassifier               0.02
# DummyClassifier                      0.01

# %% [markdown]
# # Regression

# %%
from lazypredict.Supervised import LazyRegressor

# %%
# Load toy dataset
boston = datasets.load_boston()

# %%
# X and y split
X, y = boston.data, boston.target
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=12)

# %%
# Fit all regression models
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:02<00:00, 17.01it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.88       0.90  2.87        0.19
# RandomForestRegressor                        0.86       0.88  3.19        0.28
# XGBRegressor                                 0.86       0.87  3.20        0.06
# LGBMRegressor                                0.85       0.87  3.22        0.06
# GradientBoostingRegressor                    0.84       0.86  3.34        0.11
# BaggingRegressor                             0.84       0.86  3.38        0.05
# HistGradientBoostingRegressor                0.83       0.85  3.46        0.34
# DecisionTreeRegressor                        0.80       0.83  3.74        0.01
# AdaBoostRegressor                            0.79       0.82  3.83        0.13
# PoissonRegressor                             0.78       0.81  3.92        0.01
# ExtraTreeRegressor                           0.78       0.81  3.95        0.01
# LassoLarsIC                                  0.71       0.75  4.52        0.01
# BayesianRidge                                0.71       0.75  4.53        0.01
# ElasticNetCV                                 0.71       0.75  4.53        0.06
# LassoCV                                      0.71       0.75  4.53        0.08
# RidgeCV                                      0.71       0.75  4.53        0.01
# Ridge                                        0.71       0.75  4.53        0.01
# SGDRegressor                                 0.71       0.75  4.53        0.01
# HuberRegressor                               0.71       0.75  4.53        0.02
# LassoLarsCV                                  0.71       0.75  4.53        0.04
# TransformedTargetRegressor                   0.71       0.75  4.53        0.01
# LinearRegression                             0.71       0.75  4.53        0.01
# LarsCV                                       0.70       0.74  4.62        0.03
# Lars                                         0.70       0.74  4.62        0.01
# LinearSVR                                    0.69       0.73  4.67        0.02
# KNeighborsRegressor                          0.68       0.72  4.78        0.02
# MLPRegressor                                 0.67       0.71  4.83        0.58
# OrthogonalMatchingPursuitCV                  0.67       0.71  4.87        0.01
# RANSACRegressor                              0.63       0.68  5.10        0.06
# GammaRegressor                               0.63       0.68  5.13        0.01
# SVR                                          0.62       0.67  5.19        0.02
# Lasso                                        0.62       0.67  5.19        0.01
# NuSVR                                        0.61       0.66  5.28        0.02
# ElasticNet                                   0.61       0.66  5.30        0.01
# TweedieRegressor                             0.60       0.65  5.32        0.01
# GeneralizedLinearRegressor                   0.60       0.65  5.32        0.01
# OrthogonalMatchingPursuit                    0.41       0.48  6.50        0.01
# PassiveAggressiveRegressor                   0.17       0.28  7.67        0.01
# GaussianProcessRegressor                     0.06       0.18  8.19        0.04
# DummyRegressor                              -0.15      -0.01  9.07        0.01
# LassoLars                                   -0.15      -0.01  9.07        0.02
# KernelRidge                                 -6.20      -5.27 22.64        0.02
